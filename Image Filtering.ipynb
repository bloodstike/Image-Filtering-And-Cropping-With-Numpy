# %%
# %matplotlib inline
import numpy as np
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import imageio
import ipywidgets as wg
from IPython.display import display

# %% [markdown]
# # IMPORT THE IMAGE

# %%
photo_data = imageio.imread('./profile pic.jpg ')

# %% [markdown]
# # VIEW ORIGINAL IMAGE

# %%
plt.imshow(photo_data)

# %% [markdown]
# # FILTER

# %%
def get_value(x):
    return x.value
def filter_photo(photo_data,filter0,filter1,filter2) :
    red_mask = photo_data[:,:,0] <filter0
    green_mask = photo_data[:,:,1] < filter1
    blue_mask = photo_data[:,:,2] < filter2
    final_mask = np.logical_and(red_mask, green_mask, blue_mask)
    photo_data[final_mask] = 0
    return plt.imshow(photo_data)
def circular_filter(img):
    if (condition =='y'):
        total_rows, total_cols, total_layers = photo_data.shape
        x,y= np.ogrid[:total_rows, :total_cols]
        center_row, center_col = total_rows / 2, total_cols / 2
        dist_from_center = (x - center_row)**2 + (y - center_col)**2
        radius = (total_rows / 2)**2
        circular_mask = (dist_from_center > radius)
        photo_data[circular_mask] = 255
        return plt.imshow(photo_data)
    else:
        pass

# %%
red_filter = wg.IntSlider(description='red filter:',min=0,max=255,step=1)
red_filter
# Out:
# IntSlider(value=0, description='red filter:', max=255)

# %%
green_filter = wg.IntSlider(description='green filter:',min=0,max=255,step=1)
green_filter
# Out:
# IntSlider(value=0, description='green filter:', max=255)

# %%
blue_filter = wg.IntSlider(description='blue filter:',min=0,max=255,step=1)
blue_filter
# Out:
# IntSlider(value=0, description='blue filter:', max=255)

# %% [markdown]
# # APPLY FILTER

# %%
filter0 = get_value(red_filter)
filter1 = get_value(green_filter)
filter2 = get_value(blue_filter)
filter_photo(photo_data,filter0,filter1,filter2)

# %% [markdown]
# # CIRCULAR FILTER

# %%
condition = str(input('do you want a circular filtre in the midlle: y/n'))
if (condition=='y'):
    circular_filter(img)
    Image.fromarray(photo_data).save('result.png')
# Out:
# do you want a circular filtre in the midlle: y/ny
